# %%
#matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib_inline import backend_inline
from matplotlib.axes import Axes
from matplotlib.figure import Figure

backend_inline.set_matplotlib_formats('svg')

# %%
arr = [
1, 0.16276183402913066, 0.8123809523809524, 0.9469047619047619,
2, 0.2453339456673636, 0.9424702380952381, 0.971547619047619,
3, 0.14291816565666365, 0.9573809523809523, 0.9754761904761905,
4, 0.05106023039510699, 0.9650297619047619, 0.9771428571428571,
5, 0.07435948900128525, 0.9720833333333333, 0.9792857142857143,
6, 0.078601536564506, 0.9747916666666666, 0.9805952380952381,
7, 0.021921386661485076, 0.976577380952381, 0.9829761904761904,
8, 0.07966781051444019, 0.9794642857142857, 0.9840476190476191,
9, 0.015253065937025703, 0.9805059523809524, 0.9847619047619047,
10, 0.03230213861455418, 0.9844940476190476, 0.9857142857142858,
11, 0.053590677200370695, 0.9855654761904762, 0.9857142857142858,
12, 0.0034652852613669682, 0.9861309523809524, 0.9863095238095239,
13, 0.07878989838564714, 0.9864285714285714, 0.9867857142857143,
14, 0.04806223311949376, 0.9856547619047619, 0.9859523809523809,
15, 0.0701420208120167, 0.9872619047619048, 0.9866666666666667,
16, 0.007772517748703148, 0.9872321428571429, 0.9855952380952381,
17, 0.0038898406431832483, 0.9885119047619048, 0.9871428571428571,
18, 0.006649365524003942, 0.9885119047619048, 0.986547619047619,
19, 0.04346971646962271, 0.9882738095238095, 0.9875,
20, 0.008472484439952216, 0.9891071428571429, 0.9872619047619048,
21, 0.04228847536595756, 0.9894345238095238, 0.9872619047619048,
22, 0.03913059206268351, 0.9894047619047619, 0.9870238095238095,
23, 0.016913712849155327, 0.9901785714285715, 0.9872619047619048,
24, 0.04242533789027825, 0.9899404761904762, 0.9875,
25, 0.008750689258266872, 0.9907738095238096, 0.9877380952380952,
]
x = np.array(
    [arr[i] for i in range(0, 100, 4)]
)
loss = np.array(
    [arr[i] for i in range(1, 100, 4)]
)
train_acc = np.array(
    [arr[i] for i in range(2, 100, 4)]
)
valid_acc = np.array(
    [arr[i] for i in range(3, 100, 4)]
)

# %%
fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot()
ax.plot(x, loss, label='loss')
ax.plot(x, train_acc, label='train_acc')
ax.plot(x, valid_acc, label='valid_acc')
ax.set_xlabel('epoch')
ax.set_ybound(0, 1)
ax.legend()
fig.savefig('train.svg')
